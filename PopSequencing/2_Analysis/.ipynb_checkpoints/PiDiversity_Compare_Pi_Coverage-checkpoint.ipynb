# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scipy.special
import glob
#import bioinfokit 
from bioinfokit import analys, visuz

pd.options.mode.chained_assignment = None  # default='warn'

pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',117)

# %% [markdown]
# ## What this script does:

# %% [markdown]
#     - it reads in the coverage & the pi diversity per sample for single samples and subsampled samples
#     - it shows how pi depends on the coverage

# %%
# read in data to panda
# get the number of unclassified reads from Kraken2 outputs

## from trimmed reads
InCov="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Coverage/fromTrimmedReads/Reads_and_Coverage_fromPython.pkl"
##### alternatives: 
#   InCov="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/Coverage_fromThomas.txt"
## from mapping
#   InCov="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Coverage/fromMapping/out/Coverage_collect.pkl"

## get the genetic diversity
## ## ## from single samples
#InPi_default="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_output/PiDiversity_singleData_20240527.pkl"
InPi_default="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/PiDiv_May24/O_output/PiDiversity_singleData_20240701.pkl"
## ## ## from subsampling
InPi_change1="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/PiDiv_May24/O_output/PiDiversity_Overviewsub35_20240530.pkl"
InPi_change2="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_output/PiDiv_May24/PiDiversity_Overviewsub50_20240530.pkl"
InPi_change3="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_output/PiDiv_May24/PiDiversity_Overviewsub100_20240530.pkl"

## here, I looked at how pi changes for different pool size and coverage
#InPi_change1="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_output/PiDiversity_maxCov500_Pool100.pkl"
#InPi_change2="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_output/PiDiversity_maxCov500_Pool1000.pkl"
#InPi_change3="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_output/PiDiversity_maxCov800_Pool500.pkl"

# %%
## get all the data
df_PiDefault = pd.read_pickle(InPi_default)
df_change1 = pd.read_pickle(InPi_change1)
df_change2 = pd.read_pickle(InPi_change2)
df_change3 = pd.read_pickle(InPi_change3)

#df_cov=pd.read_csv(InCov,delimiter="\t", na_values="na")
df_cov=pd.read_pickle(InCov)

df_cov = df_cov.reset_index()
df_cov.rename(columns={'index': 'ID'}, inplace=True)
df_cov = df_cov[["ID","institution","treatment","replicate","week","coverage"]]

## for the one from mapping
#df_cov.rename(columns={'sample': 'ID', 'mean': 'coverage'}, inplace=True)
#df_cov = df_cov[['ID','coverage']]
print(df_cov[df_cov["coverage"]<35].shape[0])
print(df_cov[df_cov["coverage"]<=50].shape[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 ## get all the data
#       2 df_PiDefault = pd.read_pickle(InPi_default)
# ----> 3 df_change1 = pd.read_pickle(InPi_change1)
#       4 df_change2 = pd.read_pickle(InPi_change2)
#       5 df_change3 = pd.read_pickle(InPi_change3)
#
# File ~/Documents/postDoc_Amsterdam/B_BioInfo/1_MyScripts/python/PipelineCelegans/manhattan2/lib/python3.10/site-packages/pandas/io/pickle.py:185, in read_pickle(filepath_or_buffer, compression, storage_options)
#     123 """
#     124 Load pickled pandas object (or any object) from file.
#     125
#    (...)
#     182 4    4    9
#     183 """
#     184 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 185 with get_handle(
#     186     filepath_or_buffer,
#     187     "rb",
#     188     compression=compression,
#     189     is_text=False,
#     190     storage_options=storage_options,
#     191 ) as handles:
#     192     # 1) try standard library Pickle
#     193     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     194     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     196     try:
#     197         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     198         try:
#
# File ~/Documents/postDoc_Amsterdam/B_BioInfo/1_MyScripts/python/PipelineCelegans/manhattan2/lib/python3.10/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_output/PiDiv_May24/PiDiversity_Overviewsub35_20240530.pkl'

# %%
## merge the data frames
df_merge_all = pd.merge(df_PiDefault, df_cov, on="ID", how="outer")
df_merge_all_butnotall = pd.merge(df_merge_all, df_change1, on="ID", how="inner")
df_merge_change1 = pd.merge(df_change1, df_cov, on="ID", how="outer")
df_merge_change2 = pd.merge(df_change2, df_cov, on="ID", how="outer")
df_merge_change3 = pd.merge(df_change3, df_cov, on="ID", how="outer")

df_merge_change1
# Out:
#                  ID institution_x treatment_x  inst_treat  week_x  rep  \
# 0      Gent_bb_15_1          Gent          bb     Gent_bb    15.0    1
# 1      Gent_bb_15_2          Gent          bb     Gent_bb    15.0    2
# 2      Gent_bb_15_3          Gent          bb     Gent_bb    15.0    3
# 3      Gent_bb_15_4          Gent          bb     Gent_bb    15.0    4
# 4      Gent_bb_15_5           NaN         NaN         NaN     NaN  NaN
# 5       Gent_bb_1_1          Gent          bb     Gent_bb     1.0    1
# 6       Gent_bb_1_2          Gent          bb     Gent_bb     1.0    2
# 7       Gent_bb_1_3          Gent          bb     Gent_bb     1.0    3
# 8       Gent_bb_1_4          Gent          bb     Gent_bb     1.0    4
# 9     Gent_iso_15_1          Gent         iso    Gent_iso    15.0    1
# 10    Gent_iso_15_2          Gent         iso    Gent_iso    15.0    2
# 11    Gent_iso_15_3          Gent         iso    Gent_iso    15.0    3
# 12    Gent_iso_15_4          Gent         iso    Gent_iso    15.0    4
# 13    NIOO_A00_15_1          NIOO         A00    NIOO_A00    15.0    1
# 14    NIOO_A00_15_2          NIOO         A00    NIOO_A00    15.0    2
# 15    NIOO_A00_15_3          NIOO         A00    NIOO_A00    15.0    3
# 16    NIOO_A00_15_4          NIOO         A00    NIOO_A00    15.0    4
# 17    NIOO_A00_15_5          NIOO         A00    NIOO_A00    15.0    5
# 18     NIOO_A00_1_1          NIOO         A00    NIOO_A00     1.0    1
# 19     NIOO_A00_1_2          NIOO         A00    NIOO_A00     1.0    2
# 20     NIOO_A00_1_3          NIOO         A00    NIOO_A00     1.0    3
# 21     NIOO_A00_1_4          NIOO         A00    NIOO_A00     1.0    4
# 22     NIOO_A00_1_5          NIOO         A00    NIOO_A00     1.0    5
# 23    NIOO_M00_15_1          NIOO         M00    NIOO_M00    15.0    1
# 24    NIOO_M00_15_3          NIOO         M00    NIOO_M00    15.0    3
# 25    NIOO_M00_15_4          NIOO         M00    NIOO_M00    15.0    4
# 26    NIOO_M00_15_5          NIOO         M00    NIOO_M00    15.0    5
# 27     NIOO_M00_1_1          NIOO         M00    NIOO_M00     1.0    1
# 28     NIOO_M00_1_3          NIOO         M00    NIOO_M00     1.0    3
# 29     NIOO_M00_1_4          NIOO         M00    NIOO_M00     1.0    4
# 30     NIOO_M00_1_5          NIOO         M00    NIOO_M00     1.0    5
# 31     NIOO_bb_15_1          NIOO          bb     NIOO_bb    15.0    1
# 32     NIOO_bb_15_3          NIOO          bb     NIOO_bb    15.0    3
# 33     NIOO_bb_15_4          NIOO          bb     NIOO_bb    15.0    4
# 34      NIOO_bb_1_1          NIOO          bb     NIOO_bb     1.0    1
# 35      NIOO_bb_1_3          NIOO          bb     NIOO_bb     1.0    3
# 36      NIOO_bb_1_4          NIOO          bb     NIOO_bb     1.0    4
# 37      RUG_bb_15_1           RUG          bb      RUG_bb    15.0    1
# 38      RUG_bb_15_2           RUG          bb      RUG_bb    15.0    2
# 39      RUG_bb_15_3           NaN         NaN         NaN     NaN  NaN
# 40      RUG_bb_15_4           RUG          bb      RUG_bb    15.0    4
# 41      RUG_bb_15_5           RUG          bb      RUG_bb    15.0    5
# 42       RUG_bb_1_1           RUG          bb      RUG_bb     1.0    1
# 43       RUG_bb_1_2           RUG          bb      RUG_bb     1.0    2
# 44       RUG_bb_1_4           RUG          bb      RUG_bb     1.0    4
# 45       RUG_bb_1_5           RUG          bb      RUG_bb     1.0    5
# 46      UVA_anc_0_1           UVA         anc     UVA_anc     0.0    1
# 47      UVA_anc_0_2           UVA         anc     UVA_anc     0.0    2
# 48      UVA_anc_0_3           UVA         anc     UVA_anc     0.0    3
# 49       UVA_bb_0_1           UVA          bb      UVA_bb     0.0    1
# 50        VU_bb_0_1            VU          bb       VU_bb     0.0    1
# 51        VU_bb_0_2            VU          bb       VU_bb     0.0    2
# 52        VU_bb_0_3            VU          bb       VU_bb     0.0    3
# 53        VU_bb_0_4            VU          bb       VU_bb     0.0    4
# 54        VU_bb_0_5            VU          bb       VU_bb     0.0    5
# 55       VU_bb_15_1            VU          bb       VU_bb    15.0    1
# 56       VU_bb_15_2            VU          bb       VU_bb    15.0    2
# 57       VU_bb_15_3            VU          bb       VU_bb    15.0    3
# 58       VU_bb_15_4            VU          bb       VU_bb    15.0    4
# 59       VU_bb_15_5            VU          bb       VU_bb    15.0    5
# 60        VU_bb_1_1            VU          bb       VU_bb     1.0    1
# 61        VU_bb_1_2            VU          bb       VU_bb     1.0    2
# 62        VU_bb_1_3            VU          bb       VU_bb     1.0    3
# 63        VU_bb_1_4            VU          bb       VU_bb     1.0    4
# 64        VU_bb_1_5            VU          bb       VU_bb     1.0    5
# 65      VU_bn50_0_1            VU        bn50     VU_bn50     0.0    1
# 66      VU_bn50_0_2            VU        bn50     VU_bn50     0.0    2
# 67      VU_bn50_0_3            VU        bn50     VU_bn50     0.0    3
# 68      VU_bn50_0_4            VU        bn50     VU_bn50     0.0    4
# 69      VU_bn50_0_5            VU        bn50     VU_bn50     0.0    5
# 70     VU_bn50_15_1            VU        bn50     VU_bn50    15.0    1
# 71     VU_bn50_15_2            VU        bn50     VU_bn50    15.0    2
# 72     VU_bn50_15_3            VU        bn50     VU_bn50    15.0    3
# 73     VU_bn50_15_4            VU        bn50     VU_bn50    15.0    4
# 74     VU_bn50_15_5            VU        bn50     VU_bn50    15.0    5
# 75       VU_bn5_0_1            VU         bn5      VU_bn5     0.0    1
# 76       VU_bn5_0_2            VU         bn5      VU_bn5     0.0    2
# 77       VU_bn5_0_3            VU         bn5      VU_bn5     0.0    3
# 78       VU_bn5_0_4            VU         bn5      VU_bn5     0.0    4
# 79       VU_bn5_0_5           NaN         NaN         NaN     NaN  NaN
# 80      VU_bn5_15_1            VU         bn5      VU_bn5    15.0    1
# 81      VU_bn5_15_2            VU         bn5      VU_bn5    15.0    2
# 82      VU_bn5_15_3            VU         bn5      VU_bn5    15.0    3
# 83      VU_bn5_15_4            VU         bn5      VU_bn5    15.0    4
# 84      VU_bn5_15_5            VU         bn5      VU_bn5    15.0    5
# 85      WUR_bb_15_1           WUR          bb      WUR_bb    15.0    1
# 82        0.000720              2209.0                0.0            VU
# 83        0.002845                 4.0                0.0            VU
# 84        0.001289               178.0                0.0            VU
# 85        0.002347                26.0                0.0           WUR
# 86        0.002676                 8.0                0.0           WUR
# 87        0.002875                 6.0                0.0           WUR
# 88        0.003102                 4.0                0.0           WUR
# 89        0.003008                 4.0                0.0           WUR
# 90        0.002895                 4.0                0.0           WUR
# 91        0.002983                 4.0                0.0           WUR
# 92        0.002330                19.0                0.0           WUR
#
#    treatment_y replicate week_y    coverage
# 0           bb         1     15  111.064662
# 1           bb         2     15  123.782224
# 2           bb         3     15  103.134254
# 3           bb         4     15  112.559776
# 4           bb         5     15  108.856907
# 5           bb         1      1  277.081712
# 6           bb         2      1  150.633462
# 7           bb         3      1  210.354344
# 8           bb         4      1  228.824043
# 9          iso         1     15  138.829437
# 10         iso         2     15   82.854642
# 11         iso         3     15   71.576110
# 12         iso         4     15   41.444191
# 13         A00         1     15   21.789504
# 14         A00         2     15  167.991356
# 15         A00         3     15  118.666047
# 16         A00         4     15  188.924185
# 17         A00         5     15   42.845448
# 18         A00         1      1   72.269429
# 19         A00         2      1   72.295709
# 20         A00         3      1   71.109179
# 21         A00         4      1   23.910003
# 22         A00         5      1   54.305094
# 23         M00         1     15   84.695303
# 24         M00         3     15  112.912397
# 25         M00         4     15   92.672813
# 26         M00         5     15  188.693263
# 27         M00         1      1   20.763093
# 28         M00         3      1   10.491992
# 29         M00         4      1    9.926993
# 30         M00         5      1   12.935134
# 31          bb         1     15   79.472675
# 32          bb         3     15   38.511431
# 33          bb         4     15  141.825350
# 34          bb         1      1   86.002280
# 35          bb         3      1  117.662610
# 36          bb         4      1   25.558647
# 37          bb         1     15  102.098939
# 38          bb         2     15  117.005759
# 39          bb         3     15  113.994571
# 40          bb         4     15  115.114757
# 41          bb         5     15  125.246984
# 42          bb         1      1  220.663910
# 43          bb         2      1  225.792785
# 44          bb         4      1  193.122144
# 45          bb         5      1  210.255855
# 46         anc         1      0  123.476230
# 47         anc         2      0  125.871811
# 48         anc         3      0  119.894448
# 49          bb         1      0  118.034216
# 50          bb         1      0  131.295972
# 51          bb         2      0  114.400940
# 52          bb         3      0  119.508580
# 53          bb         4      0  118.400323
# 54          bb         5      0   90.164708
# 55          bb         1     15  120.786476
# 56          bb         2     15   38.796821
# 57          bb         3     15   94.546706
# 58          bb         4     15   86.871420
# 59          bb         5     15   83.482208
# 60          bb         1      1  159.375549
# 61          bb         2      1  215.938397
# 62          bb         3      1  167.640142
# 63          bb         4      1  180.743334
# 64          bb         5      1  211.052623
# 65        bn50         1      0  169.340364
# 66        bn50         2      0   89.031610
# 67        bn50         3      0   80.956632
# 68        bn50         4      0  145.585596
# 69        bn50         5      0   57.768673
# 70        bn50         1     15   50.678023
# 71        bn50         2     15  121.812677
# 72        bn50         3     15  134.258580
# 73        bn50         4     15   96.049458
# 74        bn50         5     15   58.554474
# 75         bn5         1      0  118.648125
# 76         bn5         2      0  168.296035
# 77         bn5         3      0  197.007239
# 78         bn5         4      0  151.380869
# 79         bn5         5      0  133.168540
# 80         bn5         1     15   45.644465
# 81         bn5         2     15  125.760009
# 82         bn5         3     15   30.427735
# 83         bn5         4     15  105.850491
# 84         bn5         5     15   41.798152
# 85          bb         1     15   73.746930
# 86          bb         2     15   90.261374
# 87          bb         3     15  120.882055
# 88          bb         1      1  234.461230
# 89          bb         2      1  211.428821
# 90          bb         3      1  154.678132
# 91      bleach         1     15  121.844713
# 92      bleach         2     15   61.318614

# %%
df_woNIOO = df_merge_all[df_merge_all["institution_x"]!="NIOO"]
df_woNIOO_cut =  df_woNIOO[df_woNIOO["coverage"]>35]
np.nanmean(df_woNIOO_cut["piNorm_mean"].values)
# Out:
# 0.0016879189759952183

# %%
## 1. How does the normalized pi diversity look depending on coverage per institution

## what is the mean of all samples that are not NIOO and not below 35?
df_woNIOO = df_merge_all[df_merge_all["institution_x"]!="NIOO"]
df_woNIOO_cut =  df_woNIOO[df_woNIOO["coverage"]>35]
mean_woNIOO = np.nanmean(df_woNIOO_cut["piNorm_mean"].values)
std_woNIOO = np.nanstd(df_woNIOO_cut["piNorm_mean"].values)

plt.rcParams.update({'font.size': 12})

fig6, ax6 = plt.subplots(1,2,figsize=(16,6), sharey=True,constrained_layout = True)
sns.scatterplot(df_woNIOO, x="coverage",y="piNorm_mean", ax=ax6[0], 
                hue="inst_treat", s=50, palette="colorblind")
ax6[0].plot([35,35],[0.001,0.0018],"k--")
ax6[0].plot([0,290],[mean_woNIOO,mean_woNIOO],"k--", alpha=0.4)

sns.scatterplot(df_merge_all[df_merge_all["institution_x"]=="NIOO"], x="coverage",y="piNorm_mean", ax=ax6[1],
                hue="inst_treat", s=50, palette="bright")
ax6[1].plot([35,35],[0.001,0.0018],"k--")
ax6[1].plot([0,290],[mean_woNIOO,mean_woNIOO],"k--", alpha=0.4)
# Move the legend to an empty part of the plot
ax6[0].legend(bbox_to_anchor=(0, 1.2), loc='upper left', ncol=5)
ax6[1].legend(bbox_to_anchor=(0.15, 1.15), loc='upper left', ncol=3)

ax6[0].set_ylabel("pi diversity")
ax6[1].set_ylabel("pi diversity")
sns.despine(trim=True)

# %%
## 1. How does the normalized pi diversity look depending on coverage per institution

plt.rcParams.update({'font.size': 10})

fig10, ax10 = plt.subplots(figsize=(8,4), sharey=True,constrained_layout = True)
sns.scatterplot(df_merge_all, x="coverage",y="piNorm_mean", ax=ax10, 
                hue="institution_x", s=50, palette="colorblind")
ax10.plot([35,35],[0.001,0.0018],"k--")


sns.scatterplot(df_merge_all[df_merge_all["institution_x"]=="NIOO"], x="coverage",y="piNorm_mean", ax=ax6[1],
                hue="inst_treat", s=50, palette="bright")
ax10.legend(bbox_to_anchor=(1.1, 0.5), loc='right', ncol=1)
ax10.set_ylabel("pi diversity")
ax10.set_xlabel("original genome-wide coverage")
ax10.set_xlim([0,340])

sns.despine(trim=True)
fig10.savefig("/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_plots/Pi_pi_cov_Colored_institution.png",dpi=300)

# %%
## why does something weird happen with Vn bn50 and Vn bn 5 when subsampling to 35?

## what is the mean of all samples that are not NIOO and not below 35?
df_ch1_woVU = df_merge_change1[df_merge_all["institution_x"]!="VU"]
df_ch1_woVU_cut =  df_ch1_woVU[df_ch1_woVU["coverage"]>35]

plt.rcParams.update({'font.size': 12})

fig6, ax6 = plt.subplots(1,2,figsize=(16,6), sharey=True,constrained_layout = True)
sns.scatterplot(df_ch1_woVU, x="coverage",y="piNorm_mean", ax=ax6[0], 
                hue="inst_treat", s=50, palette="colorblind")

sns.scatterplot(df_merge_change1[df_ch1_woNIOO["institution_x"]=="NIOO"], x="coverage",y="piNorm_mean", ax=ax6[1],
                hue="inst_treat", s=50, palette="bright")
#ax6[1].plot([35,35],[0.001,0.0018],"k--")
#ax6[1].plot([0,290],[mean_ch1_woNIOO,mean_ch1_woNIOO],"k--", alpha=0.4)
## Move the legend to an empty part of the plot
#ax6[0].legend(bbox_to_anchor=(0, 1.2), loc='upper left', ncol=5)
#ax6[1].legend(bbox_to_anchor=(0.15, 1.15), loc='upper left', ncol=3)
#
#ax6[0].set_ylabel("pi diversity")
#ax6[1].set_ylabel("pi diversity")
#sns.despine(trim=True)
# Out:
# <Axes: xlabel='coverage', ylabel='piNorm_mean'>

# %%
## hypothesis: different treatments start out with different diversity from the start:

fig1, ax1 = plt.subplots(2,2, figsize=(16,10), sharex=True, sharey=True)
#sns.scatterplot(df_merge_all, x="coverage",y="pi_mean", ax=ax1[0,0], color=".2")
p1 = sns.scatterplot(df_merge_all, x="coverage",y="piNorm_mean", ax=ax1[0,0], color="blue", marker="p",label="pi")
p2 = sns.scatterplot(df_merge_all, x="coverage",y="piNormwNaN_mean", ax=ax1[0,0], color="magenta", marker="+", s=50, label="pi with NaN")
ax1[0,0].plot([35,35],[0,0.0018],"k--")
ax1[0,0].set_ylim([0,0.0019])
ax1[0,0].legend()
ax1[0,0].set_title("no subsampling")
ax1[0,0].legend(bbox_to_anchor=(1.22, -0.2), loc='lower right', ncol=1)
#sns.scatterplot(df_merge_change1, x="coverage",y="piNormwNaN_mean", ax=ax1, color=".2")
#sns.scatterplot(df_merge_change1, x="coverage",y="pi_mean", ax=ax1[0,1], color=".2")
sns.scatterplot(df_merge_change1, x="coverage",y="piNorm_mean", ax=ax1[0,1], color="blue", marker="p")
sns.scatterplot(df_merge_change1, x="coverage",y="piNormwNaN_mean", ax=ax1[0,1], color="magenta", marker="+", s=50)
ax1[0,1].plot([35,35],[0,0.0018],"k--")
ax1[0,1].set_title("subsample 35")
ax1[0,0].set_ylabel("genetic diversity")
ax1[1,0].set_ylabel("genetic diversity")
ax1[1,0].set_xlabel("original genome-wide coverage")
ax1[1,1].set_xlabel("original genome-wide coverage")

#sns.scatterplot(df_merge_change2, x="coverage",y="pi_mean", ax=ax1[1,0], color=".2")
sns.scatterplot(df_merge_change2, x="coverage",y="piNorm_mean", ax=ax1[1,0], color="blue", marker="p")
sns.scatterplot(df_merge_change2, x="coverage",y="piNormwNaN_mean", ax=ax1[1,0], color="magenta", marker="+", s=50)
ax1[1,0].plot([35,35],[0,0.0018],"k--")
ax1[1,0].set_title("subsample 50")

#sns.scatterplot(df_merge_change3, x="coverage",y="pi_mean", ax=ax1[1,1], color=".2")
sns.scatterplot(df_merge_change3, x="coverage",y="piNorm_mean", ax=ax1[1,1], color="blue", marker="p")
sns.scatterplot(df_merge_change3, x="coverage",y="piNormwNaN_mean", ax=ax1[1,1], color="magenta", marker="+", s=50)
ax1[1,1].plot([35,35],[0,0.0018],"k--")
#ax1[1,1].set_ylim([0.0008,0.0018])
ax1[1,1].set_title("subsample 100")
sns.despine(trim=True)
#fig1.savefig("/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_plots/Pi_subsample_Overview_pi_vs_cov.png",dpi=300)

# %%
## now get how strong the values differ from each other:
fig2, ax2 = plt.subplots(figsize=(8,6))
plt.scatter(df_merge_all["coverage"].values, df_merge_all["pi_mean"].values - df_merge_all["piNorm_mean"].values, color="blue", marker="p")
plt.scatter(df_merge_all["coverage"].values, df_merge_all["pi_mean"].values - df_merge_all["piNormwNaN_mean"].values, color="magenta", marker="+")
ax2.plot([35,35],[0,0.0004],"k--")
#sns.scatterplot(df_merge_all, x="coverage",y="piNormwNaN_mean", ax=ax1, color="magenta", marker="+")
#ax2.set_yscale('log')

# %%
## hypothesis: different treatments start out with different diversity from the start:

fig3, ax3 = plt.subplots(figsize=(8,6))
sns.scatterplot(df_merge_all, x="coverage",y="piNorm_mean", ax=ax3, color=".2")
sns.scatterplot(df_merge_change1, x="coverage",y="piNorm_mean", ax=ax3, color="gray", marker="p")
sns.scatterplot(df_merge_change2, x="coverage",y="piNorm_mean", ax=ax3, color="orange", marker="o")
ax3.plot([35,35],[0.0002,0.0018],"k--")
#sns.scatterplot(df_merge_change3, x="coverage",y="piNorm_mean", ax=ax3, color="magenta", marker="+")


#sns.scatterplot(df_merge_change1, x="coverage",y="piNormwNaN_mean", ax=ax1, color=".2")
#sns.despine(offset=5, trim=True)

# %%
fig4, ax4 = plt.subplots(1,2,figsize=(14,6))
sns.scatterplot(df_merge_all, x="NumNaNWindows",y="piNorm_mean", ax=ax4[0], color=".2")
sns.scatterplot(df_merge_change1, x="NumNaNWindows_mean",y="piNorm_mean", ax=ax4[0], color="gray", marker="p")
sns.scatterplot(df_merge_change2, x="NumNaNWindows_mean",y="piNorm_mean", ax=ax4[0], color="orange", marker="o")
sns.scatterplot(df_merge_change3, x="NumNaNWindows_mean",y="piNorm_mean", ax=ax4[0], color="red", marker="o")

sns.scatterplot(df_merge_all, x="NumNaNWindows",y="piNormwNaN_mean", ax=ax4[1], color=".2")
sns.scatterplot(df_merge_change1, x="NumNaNWindows_mean",y="piNormwNaN_mean", ax=ax4[1], color="gray", marker="p")
sns.scatterplot(df_merge_change2, x="NumNaNWindows_mean",y="piNormwNaN_mean", ax=ax4[1], color="orange", marker="o")
sns.scatterplot(df_merge_change3, x="NumNaNWindows_mean",y="piNormwNaN_mean", ax=ax4[1], color="red", marker="o")
# Out:
# <Axes: xlabel='NumNaNWindows', ylabel='piNormwNaN_mean'>

# %%
## How much information is lost?

fig5, ax5 = plt.subplots(figsize=(8,6))
sns.scatterplot(df_merge_all, x="coverage",y="NumNaNWindows", ax=ax5, color=".2",label="no subsampling")
sns.scatterplot(df_merge_change1, x="coverage",y="NumNaNWindows_mean", ax=ax5, color="gray", marker="p", label="subsample cov. = 35")
sns.scatterplot(df_merge_change2, x="coverage",y="NumNaNWindows_mean", ax=ax5, color="orange", marker="o", label="subsample cov. = 50")
sns.scatterplot(df_merge_change3, x="coverage",y="NumNaNWindows_mean", ax=ax5, color="red", marker="1", s=50, label="subsample cov. = 100")
ax5.legend()
ax5.set_ylabel("mean number of NaN windows")
ax5.set_xlabel("original genome-wide coverage")
ax5.plot([35,35],[0,10000],"k--")
sns.despine(trim=True)
#fig5.savefig("/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/O_plots/Subsample_NaNs_vs_cov.png",dpi=300)

# %%
df_cov.sort_values(by=['coverage'])
# Out:
#                  ID institution treatment replicate week    coverage
# 25     NIOO_M00_1_4        NIOO       M00         4    1    9.926993
# 24     NIOO_M00_1_3        NIOO       M00         3    1   10.491992
# 26     NIOO_M00_1_5        NIOO       M00         5    1   12.935134
# 23     NIOO_M00_1_1        NIOO       M00         1    1   20.763093
# 18    NIOO_A00_15_1        NIOO       A00         1   15   21.789504
# 16     NIOO_A00_1_4        NIOO       A00         4    1   23.910003
# 33      NIOO_bb_1_4        NIOO        bb         4    1   25.558647
# 72      VU_bn5_15_3          VU       bn5         3   15   30.427735
# 35     NIOO_bb_15_3        NIOO        bb         3   15   38.511431
# 61       VU_bb_15_2          VU        bb         2   15   38.796821
# 12    Gent_iso_15_4        Gent       iso         4   15   41.444191
# 74      VU_bn5_15_5          VU       bn5         5   15   41.798152
# 22    NIOO_A00_15_5        NIOO       A00         5   15   42.845448
# 70      VU_bn5_15_1          VU       bn5         1   15   45.644465
# 80     VU_bn50_15_1          VU      bn50         1   15   50.678023
# 17     NIOO_A00_1_5        NIOO       A00         5    1   54.305094
# 79      VU_bn50_0_5          VU      bn50         5    0   57.768673
# 84     VU_bn50_15_5          VU      bn50         5   15   58.554474
# 92  WUR_bleach_15_2         WUR    bleach         2   15   61.318614
# 15     NIOO_A00_1_3        NIOO       A00         3    1   71.109179
# 11    Gent_iso_15_3        Gent       iso         3   15   71.576110
# 13     NIOO_A00_1_1        NIOO       A00         1    1   72.269429
# 14     NIOO_A00_1_2        NIOO       A00         2    1   72.295709
# 88      WUR_bb_15_1         WUR        bb         1   15   73.746930
# 34     NIOO_bb_15_1        NIOO        bb         1   15   79.472675
# 77      VU_bn50_0_3          VU      bn50         3    0   80.956632
# 10    Gent_iso_15_2        Gent       iso         2   15   82.854642
# 64       VU_bb_15_5          VU        bb         5   15   83.482208
# 27    NIOO_M00_15_1        NIOO       M00         1   15   84.695303
# 31      NIOO_bb_1_1        NIOO        bb         1    1   86.002280
# 63       VU_bb_15_4          VU        bb         4   15   86.871420
# 76      VU_bn50_0_2          VU      bn50         2    0   89.031610
# 54        VU_bb_0_5          VU        bb         5    0   90.164708
# 89      WUR_bb_15_2         WUR        bb         2   15   90.261374
# 29    NIOO_M00_15_4        NIOO       M00         4   15   92.672813
# 62       VU_bb_15_3          VU        bb         3   15   94.546706
# 83     VU_bn50_15_4          VU      bn50         4   15   96.049458
# 41      RUG_bb_15_1         RUG        bb         1   15  102.098939
# 6      Gent_bb_15_3        Gent        bb         3   15  103.134254
# 73      VU_bn5_15_4          VU       bn5         4   15  105.850491
# 8      Gent_bb_15_5        Gent        bb         5   15  108.856907
# 4      Gent_bb_15_1        Gent        bb         1   15  111.064662
# 7      Gent_bb_15_4        Gent        bb         4   15  112.559776
# 28    NIOO_M00_15_3        NIOO       M00         3   15  112.912397
# 43      RUG_bb_15_3         RUG        bb         3   15  113.994571
# 51        VU_bb_0_2          VU        bb         2    0  114.400940
# 44      RUG_bb_15_4         RUG        bb         4   15  115.114757
# 42      RUG_bb_15_2         RUG        bb         2   15  117.005759
# 32      NIOO_bb_1_3        NIOO        bb         3    1  117.662610
# 49       UVA_bb_0_1         UVA        bb         1    0  118.034216
# 53        VU_bb_0_4          VU        bb         4    0  118.400323
# 65       VU_bn5_0_1          VU       bn5         1    0  118.648125
# 20    NIOO_A00_15_3        NIOO       A00         3   15  118.666047
# 52        VU_bb_0_3          VU        bb         3    0  119.508580
# 48      UVA_anc_0_3         UVA       anc         3    0  119.894448
# 60       VU_bb_15_1          VU        bb         1   15  120.786476
# 90      WUR_bb_15_3         WUR        bb         3   15  120.882055
# 81     VU_bn50_15_2          VU      bn50         2   15  121.812677
# 91  WUR_bleach_15_1         WUR    bleach         1   15  121.844713
# 46      UVA_anc_0_1         UVA       anc         1    0  123.476230
# 5      Gent_bb_15_2        Gent        bb         2   15  123.782224
# 45      RUG_bb_15_5         RUG        bb         5   15  125.246984
# 71      VU_bn5_15_2          VU       bn5         2   15  125.760009
# 47      UVA_anc_0_2         UVA       anc         2    0  125.871811
# 50        VU_bb_0_1          VU        bb         1    0  131.295972
# 69       VU_bn5_0_5          VU       bn5         5    0  133.168540
# 82     VU_bn50_15_3          VU      bn50         3   15  134.258580
# 9     Gent_iso_15_1        Gent       iso         1   15  138.829437
# 36     NIOO_bb_15_4        NIOO        bb         4   15  141.825350
# 78      VU_bn50_0_4          VU      bn50         4    0  145.585596
# 1       Gent_bb_1_2        Gent        bb         2    1  150.633462
# 68       VU_bn5_0_4          VU       bn5         4    0  151.380869
# 87       WUR_bb_1_3         WUR        bb         3    1  154.678132
# 55        VU_bb_1_1          VU        bb         1    1  159.375549
# 57        VU_bb_1_3          VU        bb         3    1  167.640142
# 19    NIOO_A00_15_2        NIOO       A00         2   15  167.991356
# 66       VU_bn5_0_2          VU       bn5         2    0  168.296035
# 75      VU_bn50_0_1          VU      bn50         1    0  169.340364
# 58        VU_bb_1_4          VU        bb         4    1  180.743334
# 30    NIOO_M00_15_5        NIOO       M00         5   15  188.693263
# 21    NIOO_A00_15_4        NIOO       A00         4   15  188.924185
# 39       RUG_bb_1_4         RUG        bb         4    1  193.122144
# 67       VU_bn5_0_3          VU       bn5         3    0  197.007239
# 40       RUG_bb_1_5         RUG        bb         5    1  210.255855
# 2       Gent_bb_1_3        Gent        bb         3    1  210.354344
# 59        VU_bb_1_5          VU        bb         5    1  211.052623
# 86       WUR_bb_1_2         WUR        bb         2    1  211.428821
# 56        VU_bb_1_2          VU        bb         2    1  215.938397
# 37       RUG_bb_1_1         RUG        bb         1    1  220.663910
# 38       RUG_bb_1_2         RUG        bb         2    1  225.792785
# 3       Gent_bb_1_4        Gent        bb         4    1  228.824043
# 85       WUR_bb_1_1         WUR        bb         1    1  234.461230
# 0       Gent_bb_1_1        Gent        bb         1    1  277.081712
