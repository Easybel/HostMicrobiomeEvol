# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scipy.special
import glob
#import bioinfokit 
from bioinfokit import analys, visuz

pd.options.mode.chained_assignment = None  # default='warn'

pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',100)

## my own function that gets the data
from Pi_GetData_fcn import GetData as GetData
from Pi_GetPiOverview_fcn import GetPiOverview as GetPiOverview

# %%
# define function
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'same')/w

# %% [markdown]
# ## What you need:
# * python functions:
#   * **Pi_GetData_fcn.py**
#   * **Pi_GetPiOverview_fcn.py**
#   * data:
#
# Comment: This script also handles theta and D diversity measures the same way! In general we call the quantity **div**, as in diversity and it can be pi, theta or D
#
# ## What this script does:
#
# - it loads diversity data with the **Pi_GetData_fcn.py** function
#   - in that function it:
#       1. shifts the window position so that it applies to the whole genome and not chromosome position
#       2. all samples are joined in one data frame
#       3. there is df_shiftRaw with the raw data for fraction (%) of window covered and diversity (e.g. pi diversity) per window
#       4. there is also df_shiftNorm in which for each window **div** is multiplied with frac
#  - Then, calculate genome-wide **div** values either with the raw data or normalised data, with **Pi_GetPiOverview_fcn.py**
#     1. **div**: uses the raw data, average ove all **div** values
#     2. **div**Weight: using the df_shiftNorm data - it evaluates:
# $$\text{div}_{weight} = \frac{\sum_{i=1}^{n}\text{div}_{i}\cdot f_{i}}{\sum_{i=1}^{n}f_{i}}$$
#       ( before, I had this, but I kicked it out: divNormwNaN: the final value is multiplied with the fraction of windows that are not nan)
#
# ![dataStructure](BioInfo.png)

# %%
# read in data to panda
InPath="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/PiDiv_May24/defaultSet_500Cov/fractioncov_0.01/"
#InPath="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/PiDiv_May24/defaultSet_500Cov/fractioncov_0.01/"
#InPath="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/PiDiv_May24/defaultSet_500Cov/fractioncov_0.01/"
#InPath="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/PiDiv_May24/defaultSet_500Cov/fractioncov_default/"
files=glob.glob(InPath+"*.pi")

outPath = "/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/PiDiv_May24/O_output/"

chromosomes=["NC_003279.8","NC_003280.10","NC_003281.10","NC_003282.8","NC_003283.11","NC_003284.9","NC_001328.1"]
chromosomes_end = [1.50750e+07, 3.03500e+07, 4.41350e+07, 6.16300e+07, 8.25550e+07, 1.00270e+08, 1.00285e+08]

len(files)
# Out:
# ['/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/D_July24/defaultSet_500Cov/fractioncov_0.01/VU_bb_1_4_Sanger_maxCov500_fracCov_0.01.D',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/D_July24/defaultSet_500Cov/fractioncov_0.01/NIOO_A00_15_2_Sanger_maxCov500_fracCov_0.01.D',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/D_July24/defaultSet_500Cov/fractioncov_0.01/Gent_iso_15_3_Sanger_maxCov500_fracCov_0.01.D']

# %%
## use the function to get the data 
samName_collect, df_shiftRaw, df_shiftNorm, collect_sumofWeights, collect_NanNum = GetData(files, chromosomes, chromosomes_end,False)
overview = GetPiOverview(samName_collect, df_shiftRaw, df_shiftNorm, collect_sumofWeights, collect_NanNum)

overview["NumNaNWindows"] =  collect_NanNum

#overview
df_shiftRaw
overview
# Out:
#                                   ID institution treatment  inst_treat  week  \
# div_VU_bb_1_4              VU_bb_1_4          VU        bb       VU_bb     1
# div_NIOO_A00_15_2      NIOO_A00_15_2        NIOO       A00    NIOO_A00    15
# div_Gent_iso_15_3      Gent_iso_15_3        Gent       iso    Gent_iso    15
# div_WUR_bleach_15_2  WUR_bleach_15_2         WUR    bleach  WUR_bleach    15
# div_NIOO_M00_1_5        NIOO_M00_1_5        NIOO       M00    NIOO_M00     1
# div_VU_bb_0_5              VU_bb_0_5          VU        bb       VU_bb     0
# div_Gent_bb_1_3          Gent_bb_1_3        Gent        bb     Gent_bb     1
# div_WUR_bb_1_3            WUR_bb_1_3         WUR        bb      WUR_bb     1
# div_NIOO_M00_1_3        NIOO_M00_1_3        NIOO       M00    NIOO_M00     1
# div_NIOO_M00_15_3      NIOO_M00_15_3        NIOO       M00    NIOO_M00    15
# div_VU_bn5_15_2          VU_bn5_15_2          VU       bn5      VU_bn5    15
# div_NIOO_M00_15_1      NIOO_M00_15_1        NIOO       M00    NIOO_M00    15
# div_NIOO_M00_15_5      NIOO_M00_15_5        NIOO       M00    NIOO_M00    15
# div_NIOO_bb_1_3          NIOO_bb_1_3        NIOO        bb     NIOO_bb     1
# div_VU_bb_15_2            VU_bb_15_2          VU        bb       VU_bb    15
# div_VU_bn5_15_1          VU_bn5_15_1          VU       bn5      VU_bn5    15
# div_VU_bb_1_5              VU_bb_1_5          VU        bb       VU_bb     1
# div_Gent_iso_15_4      Gent_iso_15_4        Gent       iso    Gent_iso    15
# div_RUG_bb_1_2            RUG_bb_1_2         RUG        bb      RUG_bb     1
# div_VU_bn50_0_4          VU_bn50_0_4          VU      bn50     VU_bn50     0
# div_VU_bn50_15_1        VU_bn50_15_1          VU      bn50     VU_bn50    15
# div_VU_bn50_0_1          VU_bn50_0_1          VU      bn50     VU_bn50     0
# div_UVA_anc_0_3          UVA_anc_0_3         UVA       anc     UVA_anc     0
# div_VU_bb_15_3            VU_bb_15_3          VU        bb       VU_bb    15
# div_NIOO_A00_1_3        NIOO_A00_1_3        NIOO       A00    NIOO_A00     1
# div_VU_bn50_0_3          VU_bn50_0_3          VU      bn50     VU_bn50     0
# div_NIOO_M00_1_4        NIOO_M00_1_4        NIOO       M00    NIOO_M00     1
# div_NIOO_bb_15_1        NIOO_bb_15_1        NIOO        bb     NIOO_bb    15
# div_VU_bb_1_3              VU_bb_1_3          VU        bb       VU_bb     1
# div_NIOO_A00_15_1      NIOO_A00_15_1        NIOO       A00    NIOO_A00    15
# div_VU_bn50_15_5        VU_bn50_15_5          VU      bn50     VU_bn50    15
# div_Gent_bb_15_3        Gent_bb_15_3        Gent        bb     Gent_bb    15
# div_VU_bb_0_1              VU_bb_0_1          VU        bb       VU_bb     0
# div_VU_bn5_15_5          VU_bn5_15_5          VU       bn5      VU_bn5    15
# div_NIOO_A00_15_3      NIOO_A00_15_3        NIOO       A00    NIOO_A00    15
# div_VU_bn5_15_3          VU_bn5_15_3          VU       bn5      VU_bn5    15
# div_WUR_bb_1_2            WUR_bb_1_2         WUR        bb      WUR_bb     1
# div_VU_bb_0_2              VU_bb_0_2          VU        bb       VU_bb     0
# div_VU_bn50_0_2          VU_bn50_0_2          VU      bn50     VU_bn50     0
# div_VU_bn5_15_4          VU_bn5_15_4          VU       bn5      VU_bn5    15
# div_Gent_bb_15_1        Gent_bb_15_1        Gent        bb     Gent_bb    15
# div_VU_bn50_15_4        VU_bn50_15_4          VU      bn50     VU_bn50    15
# div_Gent_bb_15_2        Gent_bb_15_2        Gent        bb     Gent_bb    15
# div_VU_bn5_0_4            VU_bn5_0_4          VU       bn5      VU_bn5     0
# div_NIOO_A00_1_5        NIOO_A00_1_5        NIOO       A00    NIOO_A00     1
# div_NIOO_bb_1_1          NIOO_bb_1_1        NIOO        bb     NIOO_bb     1
# div_WUR_bleach_15_1  WUR_bleach_15_1         WUR    bleach  WUR_bleach    15
# div_Gent_bb_1_4          Gent_bb_1_4        Gent        bb     Gent_bb     1
# div_RUG_bb_1_4            RUG_bb_1_4         RUG        bb      RUG_bb     1
# div_UVA_bb_0_1            UVA_bb_0_1         UVA        bb      UVA_bb     0
# div_NIOO_bb_1_4          NIOO_bb_1_4        NIOO        bb     NIOO_bb     1
# div_VU_bb_15_5            VU_bb_15_5          VU        bb       VU_bb    15
# div_RUG_bb_15_1          RUG_bb_15_1         RUG        bb      RUG_bb    15
# div_NIOO_A00_1_1        NIOO_A00_1_1        NIOO       A00    NIOO_A00     1
# div_Gent_iso_15_2      Gent_iso_15_2        Gent       iso    Gent_iso    15
# div_RUG_bb_15_2          RUG_bb_15_2         RUG        bb      RUG_bb    15
# div_RUG_bb_1_1            RUG_bb_1_1         RUG        bb      RUG_bb     1
# div_VU_bn50_15_3        VU_bn50_15_3          VU      bn50     VU_bn50    15
# div_RUG_bb_1_5            RUG_bb_1_5         RUG        bb      RUG_bb     1
# div_NIOO_bb_15_3        NIOO_bb_15_3        NIOO        bb     NIOO_bb    15
# div_WUR_bb_15_2          WUR_bb_15_2         WUR        bb      WUR_bb    15
# div_RUG_bb_15_3          RUG_bb_15_3         RUG        bb      RUG_bb    15
# div_RUG_bb_15_5          RUG_bb_15_5         RUG        bb      RUG_bb    15
# div_NIOO_M00_15_4      NIOO_M00_15_4        NIOO       M00    NIOO_M00    15
# div_Gent_bb_1_2          Gent_bb_1_2        Gent        bb     Gent_bb     1
# div_VU_bn50_15_2        VU_bn50_15_2          VU      bn50     VU_bn50    15
# div_VU_bb_0_3              VU_bb_0_3          VU        bb       VU_bb     0
# div_VU_bn5_0_5            VU_bn5_0_5          VU       bn5      VU_bn5     0
# div_UVA_anc_0_1          UVA_anc_0_1         UVA       anc     UVA_anc     0
# div_Gent_bb_15_5        Gent_bb_15_5        Gent        bb     Gent_bb    15
# div_NIOO_A00_15_4      NIOO_A00_15_4        NIOO       A00    NIOO_A00    15
# div_Gent_bb_15_4        Gent_bb_15_4        Gent        bb     Gent_bb    15
# div_NIOO_A00_15_5      NIOO_A00_15_5        NIOO       A00    NIOO_A00    15
# div_NIOO_M00_1_1        NIOO_M00_1_1        NIOO       M00    NIOO_M00     1
# div_NIOO_bb_15_4        NIOO_bb_15_4        NIOO        bb     NIOO_bb    15
# div_VU_bb_1_1              VU_bb_1_1          VU        bb       VU_bb     1
# div_VU_bb_15_4            VU_bb_15_4          VU        bb       VU_bb    15
# div_Gent_bb_1_1          Gent_bb_1_1        Gent        bb     Gent_bb     1
# div_RUG_bb_15_4          RUG_bb_15_4         RUG        bb      RUG_bb    15
# div_WUR_bb_15_3          WUR_bb_15_3         WUR        bb      WUR_bb    15
# div_VU_bb_0_4              VU_bb_0_4          VU        bb       VU_bb     0
# div_VU_bn5_0_3            VU_bn5_0_3          VU       bn5      VU_bn5     0
# div_VU_bn5_0_1            VU_bn5_0_1          VU       bn5      VU_bn5     0
# div_VU_bn5_0_2            VU_bn5_0_2          VU       bn5      VU_bn5     0
# div_NIOO_A00_1_4        NIOO_A00_1_4        NIOO       A00    NIOO_A00     1
# div_WUR_bb_1_1            WUR_bb_1_1         WUR        bb      WUR_bb     1
# div_WUR_bb_15_1          WUR_bb_15_1         WUR        bb      WUR_bb    15
# div_VU_bb_15_1            VU_bb_15_1          VU        bb       VU_bb    15
# div_VU_bn50_0_5          VU_bn50_0_5          VU      bn50     VU_bn50     0
# div_NIOO_A00_1_2        NIOO_A00_1_2        NIOO       A00    NIOO_A00     1
# div_UVA_anc_0_2          UVA_anc_0_2         UVA       anc     UVA_anc     0
# div_Gent_iso_15_1      Gent_iso_15_1        Gent       iso    Gent_iso    15
# div_VU_bb_1_2              VU_bb_1_2          VU        bb       VU_bb     1
#
#                     rep  div_mean   div_std  divWeight_mean  divWeight_std  \
# div_VU_bb_1_4         4 -0.685229  1.175462       -0.684240       1.173432
# div_NIOO_A00_15_2     2 -0.546974  1.184851       -0.545707       1.182598
# div_Gent_iso_15_3     3 -0.310570  0.985412       -0.309444       0.983208
# div_WUR_bleach_15_2   2 -0.464214  0.949391       -0.464029       0.947416
# div_NIOO_M00_1_5      5 -0.081643  0.314615       -0.086560       0.283986
# div_VU_bb_0_5         5 -0.872550  1.034748       -0.873611       1.033425
# div_Gent_bb_1_3       3 -0.863467  1.172133       -0.862555       1.170041
# div_WUR_bb_1_3        3 -0.722229  1.124397       -0.721596       1.122182
# div_NIOO_M00_1_3      3 -0.062900  0.254535       -0.065785       0.213947
# div_NIOO_M00_15_3     3 -0.816570  1.133806       -0.818886       1.129867
# div_VU_bn5_15_2       2 -0.913151  1.148467       -0.913530       1.147058
# div_NIOO_M00_15_1     1 -0.778191  1.190677       -0.780918       1.186860
# div_NIOO_M00_15_5     5 -1.324705  1.311837       -1.327164       1.310651
# div_NIOO_bb_1_3       3 -0.553314  1.092672       -0.553244       1.090743
# div_VU_bb_15_2        2 -0.381822  0.793344       -0.384355       0.790177
# div_VU_bn5_15_1       1 -0.287340  0.841337       -0.287646       0.838917
# div_VU_bb_1_5         5 -0.873502  1.165602       -0.872336       1.163352
# div_Gent_iso_15_4     4 -0.192138  0.724474       -0.191872       0.721778
# div_RUG_bb_1_2        2 -0.971602  1.174535       -0.970971       1.172709
# div_VU_bn50_0_4       4 -0.565383  1.142240       -0.564344       1.140331
samName_collect_frac = ["frac_"+s for s in samName_collect]
threshold = 0.6

df_shiftRaw_threshold = df_shiftRaw.copy()

print(df_shiftRaw_threshold.isna().sum().sum())


for i in range(len(samName_collect)):
    column = df_shiftRaw_threshold[samName_collect_frac[i]].values

    #print(np.sum(np.isnan(column)))
    column_new = np.where(column<= threshold, np.nan, column)
    #print(np.sum(np.isnan(column_new)))
    df_shiftRaw_threshold[samName_collect_frac[i]] = column_new


print(df_shiftRaw_threshold.isna().sum().sum())
df_shiftRaw_threshold
# Out:
# 206
# 6580
#                              chr  window_old       window  frac_VU_bb_1_4  \
# ID
# NC_003279.85000      NC_003279.8        5000       5000.0           0.986
# NC_003279.815000     NC_003279.8       15000      15000.0           0.999
# NC_003279.825000     NC_003279.8       25000      25000.0           1.000
# NC_003279.835000     NC_003279.8       35000      35000.0           0.998
# NC_003279.845000     NC_003279.8       45000      45000.0           1.000
# ...                          ...         ...          ...             ...
# NC_003284.917695000  NC_003284.9    17695000  100250000.0           1.000
# NC_003284.917705000  NC_003284.9    17705000  100260000.0           1.000
# NC_003284.917715000  NC_003284.9    17715000  100270000.0           0.894
# NC_001328.15000      NC_001328.1        5000  100275000.0             NaN
# NC_001328.115000     NC_001328.1       15000  100285000.0             NaN
#
#                      div_VU_bb_1_4  frac_NIOO_A00_15_2  div_NIOO_A00_15_2  \
# ID
# NC_003279.85000          -1.159296               0.963          -1.323641
# NC_003279.815000         -1.152149               1.000          -1.716023
# NC_003279.825000         -0.929561               0.994          -2.024085
# NC_003279.835000         -1.256924               0.997          -1.989783
# NC_003279.845000         -0.696650               1.000          -1.926511
# ...                            ...                 ...                ...
# NC_003284.917695000      -1.508988               1.000          -1.294059
# NC_003284.917705000      -0.317538               1.000          -0.821345
# NC_003284.917715000      -0.707823               0.894          -0.364042
# NC_001328.15000                NaN                 NaN                NaN
# NC_001328.115000          0.144790                 NaN          -0.493181
#
#                      frac_Gent_iso_15_3  div_Gent_iso_15_3  \
# ID
# NC_003279.85000                   0.981          -0.513939
# NC_003279.815000                  0.997          -0.745610
# NC_003279.825000                  0.996          -0.454572
# NC_003279.835000                  0.997          -1.106517
# NC_003279.845000                  0.999          -0.523153
# ...                                 ...                ...
# NC_003284.917695000               1.000          -0.909676
# NC_003284.917705000               1.000           0.076197
# NC_003284.917715000               0.894           0.124302
# NC_001328.15000                     NaN                NaN
# NC_001328.115000                    NaN          -2.095789
#
#                      frac_WUR_bleach_15_2  div_WUR_bleach_15_2  \
# ID
# NC_003279.85000                     0.995            -0.866311
# NC_003279.815000                    0.998            -0.005000
# NC_003279.825000                    0.996            -0.293212
# NC_003279.835000                    0.996            -0.621591
# NC_003279.845000                    1.000            -1.183995
# ...                                   ...                  ...
# NC_003284.917695000                 1.000            -1.018498
# NC_003284.917705000                 1.000            -0.516445
# NC_003284.917715000                 0.894            -0.273534
# NC_001328.15000                       NaN                  NaN
# NC_001328.115000                      NaN            -0.447915
#
#                      frac_NIOO_M00_1_5  div_NIOO_M00_1_5  frac_VU_bb_0_5  \
# ID
# NC_003279.85000                  0.917         -0.722507           0.997
# NC_003279.815000                 0.675         -0.314430           0.997
# NC_003279.825000                 0.759         -0.167860           0.998
# NC_003279.835000                 0.848         -0.682176           0.997
# NC_003279.845000                 0.829          0.117652           1.000
# ...                                ...               ...             ...
# NC_003284.917695000              0.924         -0.126618           1.000
# NC_003284.917705000              0.980          0.538970           1.000
# NC_003284.917715000              0.888          0.162671           0.894
# NC_001328.15000                  1.000         -2.970274             NaN
# NC_001328.115000                   NaN         -2.944185             NaN
#
#                      div_VU_bb_0_5  frac_Gent_bb_1_3  div_Gent_bb_1_3  \
# ID
# NC_003279.85000          -1.137652             0.981        -1.056595
# NC_003279.815000         -0.878180             1.000        -0.937004
# NC_003279.825000         -0.716263             1.000        -0.863813
# NC_003279.835000         -1.349732             0.997        -1.115097
# NC_003279.845000         -0.739916             1.000        -1.048556
# ...                            ...               ...              ...
# NC_003284.917695000      -1.162968             1.000        -1.857818
# NC_003284.917705000      -0.798479             1.000        -1.138722
# NC_003284.917715000      -0.488829             0.894        -0.580014
# NC_001328.15000                NaN               NaN              NaN
# NC_001328.115000         -0.457668               NaN         1.039361
#
#                      frac_WUR_bb_1_3  div_WUR_bb_1_3  frac_NIOO_M00_1_3  \
# ID
# NC_003279.85000                0.972       -1.268599              0.759
# NC_003279.815000               0.999       -0.402073                NaN
# NC_003279.825000               0.995       -0.734223              0.603
# NC_003279.835000               0.998       -0.725252              0.788
# NC_003279.845000               1.000       -0.617413              0.756
# ...                              ...             ...                ...
# NC_003284.917695000            1.000       -1.772370              0.944
# NC_003284.917705000            1.000       -0.322922              0.954
# NC_003284.917715000            0.893       -0.902043              0.768
# NC_001328.15000                  NaN             NaN              1.000
# NC_001328.115000                 NaN       -0.017877                NaN
#
#                      div_NIOO_M00_1_3  frac_NIOO_M00_15_3  div_NIOO_M00_15_3  \
# ID
# NC_003279.85000             -0.328472               0.938          -0.769472
# NC_003279.815000            -0.083924               0.996          -1.703278
# NC_003279.825000             0.621070               0.994          -2.236736
# NC_003279.835000            -0.069419               0.993          -2.078000
# NC_003279.845000            -0.075391               0.996          -2.622105
# ...                               ...                 ...                ...
# NC_003284.917695000         -0.130836               1.000          -1.265212
# NC_003284.917705000          0.200851               0.997          -1.863441
# NC_003284.917715000          0.060164               0.893          -1.546033
# NC_001328.15000             -2.737368                 NaN                NaN
# NC_001328.115000            -2.714536                 NaN          -1.032486
#
#                      frac_VU_bn5_15_2  div_VU_bn5_15_2  frac_NIOO_M00_15_1  \
# ID
# NC_003279.85000                 0.967        -0.997538               0.951
# NC_003279.815000                0.999        -1.307512               0.995
# NC_003279.825000                0.995        -1.341111               0.993
# NC_003279.835000                0.996        -1.797318               0.993
# NC_003279.845000                0.998        -1.319658               0.996
# ...                               ...              ...                 ...
# NC_003284.917695000             1.000        -1.531766               1.000
# NC_003284.917705000             1.000        -0.213504               0.998
# NC_003284.917715000             0.894        -0.600056               0.893
# NC_001328.15000                   NaN              NaN                 NaN
# NC_001328.115000                  NaN         0.355642                 NaN
#
#                      div_NIOO_M00_15_1  frac_NIOO_M00_15_5  div_NIOO_M00_15_5  \
# ID
# NC_003279.85000              -0.735967               0.938          -0.825637
# NC_003279.815000             -1.598129               0.998          -2.502227
# NC_003279.825000             -2.325028               0.994          -2.596632
# NC_003279.835000             -1.944440               0.994          -2.421340
# NC_003279.845000             -2.141921               0.997          -2.657464
# ...                                ...                 ...                ...
# NC_003284.917695000          -2.017297               1.000          -2.392785
# NC_003284.917705000          -2.231998               0.998          -2.599193
# NC_003284.917715000          -1.489075               0.894          -1.502127
# NC_001328.15000                    NaN                 NaN                NaN
# NC_001328.115000             -1.428329                 NaN          -1.633110
#
#                      frac_NIOO_bb_1_3  div_NIOO_bb_1_3  frac_VU_bb_15_2  \
# ID
# NC_003279.85000                 0.987        -1.099569            0.976
# NC_003279.815000                0.998        -0.238998            0.995
# NC_003279.825000                0.994        -0.851772            0.993
# NC_003279.835000                0.997        -0.601723            0.994
# NC_003279.845000                1.000        -0.735823            0.995
# ...                               ...              ...              ...
# NC_003284.917695000             1.000        -1.315822            1.000
# NC_003284.917705000             1.000        -0.195020            1.000
# NC_003284.917715000             0.894        -0.603491            0.893
# NC_001328.15000                   NaN              NaN              NaN
# NC_001328.115000                  NaN        -0.304306              NaN
#
#                      div_VU_bb_15_2  frac_VU_bn5_15_1  div_VU_bn5_15_1  \
# ID
# NC_003279.85000           -0.606266             0.978        -0.603269
# NC_003279.815000           0.062901             0.995         0.077118
# NC_003279.825000          -0.360232             0.993        -0.432862
# NC_003279.835000           0.638550             0.994        -0.891740
# NC_003279.845000          -0.421053             0.997        -0.389409
# ...                             ...               ...              ...
# NC_003284.917695000       -0.943780             1.000        -0.988761
# NC_003284.917705000       -0.148163             1.000        -0.202489
# NC_003284.917715000       -0.074586             0.892        -0.211334
# NC_001328.15000           -0.807046               NaN              NaN
# NC_001328.115000          -0.522620               NaN         0.141573
#
#                      frac_VU_bb_1_5  div_VU_bb_1_5  frac_Gent_iso_15_4  \
# ID
# NC_003279.85000               0.958      -1.240323               0.977
# NC_003279.815000              1.000      -1.044849               0.997
# NC_003279.825000              0.995      -1.520019               0.994
# NC_003279.835000              0.997      -1.528690               0.995
# NC_003279.845000              1.000      -1.229096               0.998
# ...                             ...            ...                 ...
# NC_003284.917695000           1.000      -1.872220               0.997
# NC_003284.917705000           1.000      -0.806499               1.000
# NC_003284.917715000           0.894      -0.546812               0.893
# NC_001328.15000                 NaN            NaN                 NaN
# NC_001328.115000                NaN      -1.018423                 NaN
#
#                      div_Gent_iso_15_4  frac_RUG_bb_1_2  div_RUG_bb_1_2  \
# ID
# NC_003279.85000              -0.558013            0.989       -1.376397
# NC_003279.815000             -0.100745            1.000       -1.203434
# NC_003279.825000             -0.095111            0.995       -1.124575
# NC_003279.835000              0.093790            0.999       -1.473258
# NC_003279.845000             -0.565226            1.000       -1.535762
# ...                                ...              ...             ...
# NC_003284.917695000          -0.526079            1.000       -1.826905
# NC_003284.917705000          -0.044698            1.000       -0.748659
# NC_003284.917715000           0.197127            0.894       -0.923688
# NC_001328.15000                    NaN              NaN             NaN
# NC_001328.115000             -0.353351              NaN       -0.584890
#
#                      frac_VU_bn50_0_4  ...  frac_NIOO_A00_15_5  \
# ID                                     ...
# NC_003279.85000                 0.998  ...               0.978
# NC_003279.815000                0.999  ...               0.984
# NC_003279.825000                1.000  ...               0.991
# NC_003279.835000                0.997  ...               0.992
# NC_003279.845000                1.000  ...               0.997
# ...                               ...  ...                 ...
# NC_003284.917695000             1.000  ...               1.000
# NC_003284.917705000             1.000  ...               1.000
# NC_003284.917715000             0.894  ...               0.894
# NC_001328.15000                   NaN  ...                 NaN
# NC_001328.115000                  NaN  ...                 NaN
#
#                      div_NIOO_A00_15_5  frac_NIOO_M00_1_1  div_NIOO_M00_1_1  \
# ID
# NC_003279.85000              -1.040436              0.932         -0.529981
# NC_003279.815000             -0.591086              0.925         -0.127008
# NC_003279.825000             -0.731705              0.980          0.100910
# NC_003279.835000             -0.512525              0.945          0.190295
# NC_003279.845000             -0.559635              0.972         -0.422714
# ...                                ...                ...               ...
# NC_003284.917695000          -0.360404              0.971         -0.014464
# NC_003284.917705000          -0.245777              0.995         -0.270465
# NC_003284.917715000           0.233025              0.887          0.407482
# NC_001328.15000               0.000000              1.000         -2.863509
# NC_001328.115000              0.167745                NaN         -1.218728
#
#                      frac_NIOO_bb_15_4  div_NIOO_bb_15_4  frac_VU_bb_1_1  \
# ID
# NC_003279.85000                  0.989         -1.264573           0.991
# NC_003279.815000                 0.998         -1.241756           1.000
# NC_003279.825000                 0.999         -1.261996           0.995
# NC_003279.835000                 0.997         -1.622414           0.998
# NC_003279.845000                 1.000         -1.535655           1.000
# ...                                ...               ...             ...
# NC_003284.917695000              1.000         -1.693673           1.000
# NC_003284.917705000              1.000         -1.305834           1.000
# NC_003284.917715000              0.894         -0.532770           0.894
# NC_001328.15000                    NaN               NaN             NaN
# NC_001328.115000                   NaN         -0.537665             NaN
#
#                      div_VU_bb_1_1  frac_VU_bb_15_4  div_VU_bb_15_4  \
# ID
# NC_003279.85000          -1.030772            0.977       -0.851565
# NC_003279.815000         -0.769039            0.996       -0.809682
# NC_003279.825000         -0.650232            0.994       -1.187878
# NC_003279.835000         -0.432567            0.995       -1.556616
# NC_003279.845000         -0.866733            1.000       -1.286463
# ...                            ...              ...             ...
# NC_003284.917695000      -1.493570            1.000       -1.645423
# NC_003284.917705000      -0.361317            1.000       -0.649001
# NC_003284.917715000      -0.681195            0.894       -0.354550
# NC_001328.15000                NaN              NaN             NaN
# NC_001328.115000          0.777481              NaN       -1.001668
#
#                      frac_Gent_bb_1_1  div_Gent_bb_1_1  frac_RUG_bb_15_4  \
# ID
# NC_003279.85000                 0.972        -0.878097             0.976
# NC_003279.815000                1.000        -1.214494             0.998
# NC_003279.825000                1.000        -1.564969             0.995
# NC_003279.835000                0.998        -2.016668             0.997
# NC_003279.845000                1.000        -1.391259             1.000
# ...                               ...              ...               ...
# NC_003284.917695000             1.000        -1.130121             1.000
# NC_003284.917705000             1.000        -0.727734             1.000
# NC_003284.917715000             0.894        -0.319348             0.894
# NC_001328.15000                   NaN              NaN               NaN
# NC_001328.115000                  NaN        -0.041136               NaN
#
#                      div_RUG_bb_15_4  frac_WUR_bb_15_3  div_WUR_bb_15_3  \
# ID
# NC_003279.85000            -1.294136             0.983        -1.218671
# NC_003279.815000           -0.495855             0.999        -0.645265
# NC_003279.825000           -0.802757             0.994        -0.923225
# NC_003279.835000           -0.558670             0.996        -1.435920
# NC_003279.845000           -1.476678             0.999        -1.125086
# ...                              ...               ...              ...
# NC_003284.917695000        -1.514156             1.000        -1.590984
# NC_003284.917705000        -0.844829             1.000         0.057616
# NC_003284.917715000        -0.848225             0.894        -0.592270
# NC_001328.15000                  NaN               NaN              NaN
# NC_001328.115000           -0.496983               NaN        -0.233249
#
#                      frac_VU_bb_0_4  div_VU_bb_0_4  frac_VU_bn5_0_3  \
# ID
# NC_003279.85000               0.987      -1.303005            0.963
# NC_003279.815000              0.998      -1.352344            1.000
# NC_003279.825000              0.999      -1.614252            0.995
# NC_003279.835000              0.997      -1.687048            0.997
# NC_003279.845000              0.999      -1.513114            1.000
# ...                             ...            ...              ...
# NC_003284.917695000           1.000      -1.706585            1.000
# NC_003284.917705000           1.000      -0.542828            1.000
# NC_003284.917715000           0.894      -0.705143            0.894
# NC_001328.15000                 NaN            NaN              NaN
# NC_001328.115000                NaN       0.176147              NaN
#
#                      div_VU_bn5_0_3  frac_VU_bn5_0_1  div_VU_bn5_0_1  \
# ID
# NC_003279.85000           -0.848569            0.999       -0.827923
# NC_003279.815000          -0.922554            0.999       -0.122833
# NC_003279.825000          -1.202904            0.995       -0.802265
# NC_003279.835000          -1.149725            0.997       -0.855445
# NC_003279.845000          -0.841563            1.000       -1.081578
# ...                             ...              ...             ...
# NC_003284.917695000       -1.799716            1.000       -1.019196
# NC_003284.917705000       -1.122950            1.000       -0.376886
# NC_003284.917715000       -0.101461            0.894       -0.062903
# NC_001328.15000                 NaN              NaN             NaN
# NC_001328.115000                NaN              NaN       -1.029443
#
#                      frac_VU_bn5_0_2  div_VU_bn5_0_2  frac_NIOO_A00_1_4  \
# ID
# NC_003279.85000                0.963       -1.353546              0.981
# NC_003279.815000               0.997       -1.155864              0.944
# NC_003279.825000               0.994       -1.786751              0.975
# NC_003279.835000               0.996       -1.624156              0.976
# NC_003279.845000               0.998       -1.740030              0.979
# ...                              ...             ...                ...
# NC_003284.917695000            1.000       -1.595029              0.955
# NC_003284.917705000            1.000        0.140751              0.988
# NC_003284.917715000            0.894       -0.863207              0.886
# NC_001328.15000                  NaN             NaN              0.757
# NC_001328.115000                 NaN        0.562470                NaN
#
#                      div_NIOO_A00_1_4  frac_WUR_bb_1_1  div_WUR_bb_1_1  \
# ID
# NC_003279.85000             -0.679196            0.976       -1.254906
# NC_003279.815000            -0.832295            0.999       -1.070933
# NC_003279.825000            -0.616925            1.000       -1.217957
# NC_003279.835000            -0.701737            0.998       -1.864947
# NC_003279.845000            -0.862637            1.000       -1.303778
# ...                               ...              ...             ...
# NC_003284.917695000         -0.361299            1.000       -1.860328
# NC_003284.917705000         -0.416748            1.000       -0.882840
# NC_003284.917715000         -0.207109            0.894       -0.776945
# NC_001328.15000              0.621752              NaN             NaN
# NC_001328.115000             1.120329              NaN       -1.108161
#
#                      frac_WUR_bb_15_1  div_WUR_bb_15_1  frac_VU_bb_15_1  \
# ID
# NC_003279.85000                 0.976        -0.575185            0.987
# NC_003279.815000                0.997         0.823821            0.999
# NC_003279.825000                0.993         0.945702            0.994
# NC_003279.835000                0.994         1.214810            0.998
# NC_003279.845000                0.997         1.892381            1.000
# ...                               ...              ...              ...
# NC_003284.917695000             1.000        -1.026623            1.000
# NC_003284.917705000             1.000        -0.545577            1.000
# NC_003284.917715000             0.894        -0.023290            0.894
# NC_001328.15000                   NaN              NaN              NaN
# NC_001328.115000                  NaN        -0.436379              NaN
#
#                      div_VU_bb_15_1  frac_VU_bn50_0_5  div_VU_bn50_0_5  \
# ID
# NC_003279.85000           -1.224011             0.976        -0.715681
# NC_003279.815000          -1.399698             0.996         0.202589
# NC_003279.825000          -1.446944             0.994         0.159434
# NC_003279.835000          -1.582352             0.995        -0.575394
# NC_003279.845000          -1.396524             0.998        -0.177661
# ...                             ...               ...              ...
# NC_003284.917695000       -1.806747             1.000        -0.604234
# NC_003284.917705000       -0.726585             1.000         0.194117
# NC_003284.917715000       -0.965510             0.893        -0.251040
# NC_001328.15000                 NaN               NaN              NaN
# NC_001328.115000           0.095471               NaN         0.181910
#
#                      frac_NIOO_A00_1_2  div_NIOO_A00_1_2  frac_UVA_anc_0_2  \
# ID
# NC_003279.85000                  0.976         -1.327755             0.996
# NC_003279.815000                 0.991         -1.053474             0.999
# NC_003279.825000                 0.993         -1.222710             1.000
# NC_003279.835000                 0.996         -1.183375             0.997
# NC_003279.845000                 0.997         -1.492027             0.998
# ...                                ...               ...               ...
# NC_003284.917695000              1.000         -0.194579             1.000
# NC_003284.917705000              1.000         -0.270877             1.000
# NC_003284.917715000              0.893         -0.472008             0.894
# NC_001328.15000                    NaN         -0.328581               NaN
# NC_001328.115000                   NaN         -0.590975               NaN
#
#                      div_UVA_anc_0_2  frac_Gent_iso_15_1  div_Gent_iso_15_1  \
# ID
# NC_003279.85000            -0.946792               0.964          -1.020415
# NC_003279.815000           -1.037927               0.999          -1.231571
# NC_003279.825000           -1.331385               0.995          -1.516304
# NC_003279.835000           -1.492278               0.998          -1.488799
# NC_003279.845000           -0.496424               1.000          -0.881945
# ...                              ...                 ...                ...
# NC_003284.917695000        -1.393586               1.000          -1.331810
# NC_003284.917705000         0.033333               1.000          -0.625866
# NC_003284.917715000        -0.606547               0.894          -0.311649
# NC_001328.15000                  NaN                 NaN                NaN
# NC_001328.115000           -1.746737                 NaN           0.781422
#
#                      frac_VU_bb_1_2  div_VU_bb_1_2
# ID
# NC_003279.85000               0.973      -1.393037
# NC_003279.815000              1.000      -1.057709
# NC_003279.825000              0.995      -1.243453
# NC_003279.835000              0.998      -1.157038
# NC_003279.845000              1.000      -1.589269
# ...                             ...            ...
# NC_003284.917695000           1.000      -1.874649
# NC_003284.917705000           1.000      -0.918555
# NC_003284.917715000           0.894      -0.544019
# NC_001328.15000                 NaN            NaN
# NC_001328.115000                NaN      -0.273482
#
# [10032 rows x 189 columns]

# %%
# what is the impact of the number of windows that we have to ignore?

fig2, ax2 = plt.subplots(figsize=(8,6))
sns.scatterplot(overview, x="NumNaNWindows",y="div_mean", ax=ax2)
sns.scatterplot(overview, x="NumNaNWindows",y="divWeight_mean", ax=ax2)
# Out:
# <Axes: xlabel='NumNaNWindows', ylabel='div_mean'>

# %%
## this is just here for check reasons:
### -- to see if we have data for the whole genome

samName_plot = [s for s in samName_collect if "VU_bb" in s]

f1, axx = plt.subplots(len(samName_plot),1, sharex='col', figsize=(14, 10))#, sharex=True)
windowSize=10

for i in range(len(samName_plot)):
    plot = sns.scatterplot(ax=axx[i], data=df_shiftNorm, x='window', y="divNorm"+"_"+samName_plot[i], 
                   hue='chr', palette = 'colorblind', legend=None) 
    axx[i].set_ylabel(samName_plot[i])
    movmean = moving_average(df_shiftNorm["divNorm"+"_"+samName_plot[i]], windowSize)
    axx[i].plot(np.array(df_shiftNorm['window'].values),movmean)

# %%
# only look at backbone
overviewBB = overview.loc[(overview['treatment']=="bb") | (overview['treatment']=="anc")]
overviewnotBB = overview.loc[(overview['treatment']!="bb") | (overview['treatment']=="anc")]
overviewW0 = overview.loc[(overview['week']==0)]
overviewW1 = overview.loc[(overview['week']==1)]
overviewW15 = overview.loc[(overview['week']==15)]

# %%
## hypothesis: different treatments start out with different diversity from the start:

fig1, ax1 = plt.subplots(1,2, figsize=(16,4))
plt.title('Week 0 -- comparing treatments and institutions')
sns.boxplot(data=overviewW15, x="institution", y="div_mean", hue="treatment", width=0.5, ax=ax1[0])
#sns.move_legend(ax1[0], "upper left", bbox_to_anchor=(1, 1))
sns.boxplot(data=overviewW15, x="institution", y="divWeight_mean", hue="treatment", width=0.5, ax=ax1[1])

#sns.move_legend(ax1[1], "upper left", bbox_to_anchor=(1, 1))

sns.despine(offset=5, trim=True)

# %%
### save the data:
df_shiftRaw.to_pickle(outPath + "PiDiv_df_shiftRaw_singleData_20240724.pkl")
df_shiftRaw.to_csv(outPath + "PiDiv_df_shiftRaw_singleData_20240724.csv", index=False)

df_shiftNorm.to_pickle(outPath + "PiDiv_df_shiftNorm_singleData_20240724.pkl")
df_shiftNorm.to_csv(outPath + "PiDiv_df_shiftNorm_singleData_20240724.csv", index=False)

overview.to_pickle(outPath + "PiDiv_df_overview_singleData_20240724.pkl")
overview.to_csv(outPath + "PiDiv_df_overview_singleData_20240724.csv", index=False)

# %%
outPath
# Out:
# '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/1_Dev_PipelineCelegans/Pi_Diversity/PiDiv_May24/O_output/'
