# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scipy.special
import glob

# %%
# get the number of unclassified reads from Kraken2 outputs

InPath="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/"

files=glob.glob(InPath+"*.IR.report")
files
# Out:
# ['/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bb_1_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_A00_15_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bb_0_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_A00_1_2_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn50_15_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_bb_15_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_M00_1_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bb_0_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_bb_1_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_iso_15_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/RUG_bb_15_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bb_15_2_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_bb_1_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/WUR_bb_15_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_M00_1_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/RUG_bb_15_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn5_15_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_bb_15_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn5_15_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_A00_15_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/RUG_bb_1_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn50_0_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_bb_15_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_iso_15_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bb_0_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bb_15_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/UVA_bb_0_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_bb_15_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn5_0_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_A00_15_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn5_0_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/RUG_bb_1_2_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/UVA_anc_0_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn50_15_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_M00_1_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn50_15_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_bb_1_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn50_0_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_iso_15_2_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_M00_15_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_bb_1_2_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_A00_15_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/WUR_bb_1_2_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn5_15_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn50_15_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn5_0_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/Gent_bb_15_5_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/WUR_bb_1_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_A00_1_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/UVA_anc_0_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_A00_1_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn5_0_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/RUG_bb_15_2_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/RUG_bb_15_4_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_bb_1_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bb_1_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_M00_1_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bb_1_2_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/NIOO_M00_15_3_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/VU_bn50_0_1_woCE_2plusPf.IR.report',
#  '/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/2_Metagenomics/1_taxonomy/Kraken/kraken_reports/withDB_plusPf/WUR_bb_15_1_woCE_2plusPf.IR.report']

# %%
# extract the inforamtion how many reads are unclassified
## from the first two rows

sample=[]
inst=[]
treat=[]
wee=[]
rrep=[]

firstLine=[]
secondLine=[]

uncla_reads = []
cla_reads = []

for i in range(len(files)):
    
    a = files[i].split('/')
    aa=a[-1].split('_')[0:4]
    sample.append(aa)

    inst.append(aa[0])
    treat.append(aa[1])
    wee.append(aa[2])
    rrep.append(aa[3])
    
    with open(files[i]) as input_file:
        head = [next(input_file) for _ in range(2)]
        
    first=str(head[0]).split('\t')
    second=str(head[1]).split('\t')

    # write to a list
    firstLine.append(first)
    secondLine.append(second)

    # Get the numbers out:
    if first[-1] == 'unclassified\n':
        uncla_reads.append(first[1])
    if second[-1] == 'root\n':
        cla_reads.append(second[1])

print(uncla_reads)
# Out:
# ['1378661', '2991978', '370105', '2308787', '2152760', '1073734', '2788010', '358339', '500902', '2804150', '338672', '2564828', '550878', '2464056', '3046758', '353801', '1813039', '376412', '3099728', '2631387', '952945', '2412743', '433087', '3866455', '608850', '1068026', '978297', '480944', '1098571', '1733364', '1066903', '427523', '287614', '1311087', '2078651', '644198', '1080396', '1413277', '1036787', '1162140', '934332', '2413814', '1287672', '768280', '1834623', '1123821', '498991', '948880', '2711165', '750586', '1611220', '981750', '306851', '290259', '1911652', '1982622', '2487246', '720969', '469572', '912018', '4981746']

# %%
# make a data frame because plotting could get easier :)

# get the relative proportion of unclassified reads:
all_reads = np.array(uncla_reads).astype(int)+np.array(cla_reads).astype(int)
uncla_rel = np.divide(np.array(uncla_reads).astype(int),all_reads)
df = pd.DataFrame(
    {
        'institution': inst,
        'treatment': treat,
        'week': wee,
        'rep': rrep,
        'uncla_reads': np.array(uncla_reads).astype(int),
        'cla_reads': np.array(cla_reads).astype(int), 
        'allReads': all_reads,
        'uncla_rel': uncla_rel,
    }
)
df
# Out:
#    institution treatment week rep  uncla_reads  cla_reads  allReads  uncla_rel
# 0           VU        bb    1   3      1378661   17986821  19365482   0.071192
# 1         NIOO       A00   15   5      2991978   77916785  80908763   0.036980
# 2           VU        bb    0   3       370105    2843641   3213746   0.115163
# 3         NIOO       A00    1   2      2308787   48708872  51017659   0.045255
# 4           VU      bn50   15   1      2152760   29503573  31656333   0.068004
# ..         ...       ...  ...  ..          ...        ...       ...        ...
# 56        NIOO       M00    1   3      2487246   61046984  63534230   0.039148
# 57          VU        bb    1   2       720969    6003029   6723998   0.107223
# 58        NIOO       M00   15   3       469572   17502412  17971984   0.026128
# 59          VU      bn50    0   1       912018   18221705  19133723   0.047665
# 60         WUR        bb   15   1      4981746   81922815  86904561   0.057324
#
# [61 rows x 8 columns]

# %%
# plot histogram of relative number of unclassified reads

fig1, ax1 = plt.subplots(figsize=(8,3))

sns.set_theme(style="ticks")

sns.despine(fig1)

sns.histplot(
    df,
    x="uncla_rel",
    edgecolor=".3",
    linewidth=.5,
    binwidth=0.01,
)
ax1.set_xlabel('percentage unclassified reads')
# Out:
# Text(0.5, 0, 'percentage unclassified reads')

# %%
fig2, ax2 = plt.subplots(figsize=(8,3))

sns.set_theme(style="ticks")

sns.despine(fig2)

sns.histplot(
    df,
    x='uncla_reads',
    edgecolor=".3",
    binwidth=300000
)
# Out:
# <Axes: xlabel='uncla_reads', ylabel='Count'>

# %%
# get the samples with the highest unclassified reads proportion

df.sort_values('uncla_rel')[0:20]
# Out:
#    institution treatment week rep  uncla_reads  cla_reads  allReads  uncla_rel
# 27        NIOO        bb   15   1       480944   17966162  18447106   0.026072
# 58        NIOO       M00   15   3       469572   17502412  17971984   0.026128
# 14        NIOO       M00    1   1      3046758   84648269  87695027   0.034743
# 50        NIOO       A00    1   1      1611220   42722066  44333286   0.036343
# 34        NIOO       M00    1   5      2078651   54707391  56786042   0.036605
# 1         NIOO       A00   15   5      2991978   77916785  80908763   0.036980
# 5         NIOO        bb   15   3      1073734   26860083  27933817   0.038438
# 56        NIOO       M00    1   3      2487246   61046984  63534230   0.039148
# 19        NIOO       A00   15   1      2631387   63522943  66154330   0.039776
# 41        NIOO       A00   15   4      2413814   56230590  58644404   0.041160
# 6         NIOO       M00    1   4      2788010   62369344  65157354   0.042789
# 54        NIOO        bb    1   3      1911652   41111343  43022995   0.044433
# 48        NIOO       A00    1   4      2711165   57668110  60379275   0.044902
# 3         NIOO       A00    1   2      2308787   48708872  51017659   0.045255
# 20         RUG        bb    1   4       952945   19466650  20419595   0.046668
# 59          VU      bn50    0   1       912018   18221705  19133723   0.047665
# 39        NIOO       M00   15   4      1162140   21252718  22414858   0.051847
# 29        NIOO       A00   15   3      1733364   30321260  32054624   0.054075
# 13         WUR        bb   15   3      2464056   41396075  43860131   0.056180
# 30          VU       bn5    0   4      1066903   17593782  18660685   0.057174

# %% [markdown]
# # Null-Hypothesis:
#
# - I would assume that the proportion of unclassified reads to all reads is the same across all samples. Why? Because to find unclassified ones if they are systematic (degregaded DNA, human contamination) it should depend only on the DNA amount.N
# - So: assumption: number of unclassified reads is linear with the number of all reads, so that slope is the proportion

# %%
# plot the correlation between peak fraction and % mapped reads
fig3, ax3 = plt.subplots()
#ax.set_yscale('log')

plt.scatter(df.loc[df['institution'].isin(['NIOO'])].allReads,
            df.loc[df['institution'].isin(['NIOO'])].uncla_reads,marker=6,label="NIOO")

plt.scatter(df.loc[df['institution'].isin(['VU'])].allReads,
            df.loc[df['institution'].isin(['VU'])].uncla_reads,marker=6,label="VU")

plt.scatter(df.loc[df['institution'].isin(['UVA'])].allReads,
            df.loc[df['institution'].isin(['UVA'])].uncla_reads,marker=6,label="UVA")

plt.scatter(df.loc[df['institution'].isin(['Gent'])].allReads,
            df.loc[df['institution'].isin(['Gent'])].uncla_reads,marker='o',label="Gent")

plt.scatter(df.loc[df['institution'].isin(['WUR'])].allReads,
            df.loc[df['institution'].isin(['WUR'])].uncla_reads,marker='o',label="WUR")

plt.scatter(df.loc[df['institution'].isin(['RUG'])].allReads,
            df.loc[df['institution'].isin(['RUG'])].uncla_reads,marker='o',label="RUG")


plt.plot([0,10*df.loc[:, 'allReads'].mean()],[0,10*df.loc[:, 'uncla_reads'].mean()], '--k',label="av. line")
ax3.set_xlim([0,1e8])
#ax3.set_ylim([0,0.6e7])

ax3.set_xlabel('all reads', fontsize=14)
ax3.set_ylabel('unclassified reads', fontsize=14)
df.loc[df['institution'].isin(['NIOO'])].allReads
plt.legend()

# %% [markdown]
# # Fazit:
# - there are 2(-3) institutions that deviate most from the linear null hypothesis
# - Gent (and VU a few samples): has more unclassified reads than on overage
# - NIOO has the lowest number of relative unclassified reads (even though it has the highest total number of unclassified reads)
#
# - **I think that this means that there is an additional microbial signature that is "hidden" in the unclassified reads -> maybe fungal information**
