# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scipy.special
import glob
from matplotlib import colormaps
import matplotlib.colors as mcolors

# %%
# define the outPath where to save the colors
outPath="/home/isabel/Documents/postDoc_Amsterdam/1_EvolWormJourney/1_Genomics/2_EvolGenomics/M2_colors"

# %%
## define colors:
### very strong colors for the 5 most important species
### and fill up with less specific colors:

black=np.array([0, 0, 0])/256 
blue=np.array([51,34,136])/256
cyan=np.array([136,204,238])/256
teal=np.array([68,170,153])/256
green=np.array([17,119,51])/256
olive=np.array([153,153,51])/256
yellow=np.array([238,204,102])/256
rose=np.array([204,102,119])/256
wine=np.array([136,34,85])/256
purple=np.array([170,68,153])/256
grey=np.array([221,221,221])/256
magenta=np.array([238,51,119])/256
pink=np.array([255,170,187])/256
darkyellow=np.array([153,119,0])/256
darkred=np.array([153,68,85])/256
red=np.array([204,51,17])/256
orange=np.array([238,119,51])/256
lightblue=np.array([119,179,221])/256 
lightcyan=np.array([153,221,255])/256 
mint=np.array([68,187,153])/256 
ppink=np.array([222,49,99])/256 
olive2=np.array([170,170,0])/256 
lightyellow=np.array([238,221,136])/256 
orange2=np.array([238,136,102])/256 
pink2=np.array([255,170,187])/256 
palegray=np.array([221,221,221])/256 
paleblue=np.array([187,204,238])/256 
palecyan=np.array([204,238,255])/256 
palegreen=np.array([204,221,170])/256 
paleyellow=np.array([238,238,187])/256 
palered=np.array([255,204,204])/256 
darkblue=np.array([34,34,85])/256 
darkcyan=np.array([34,85,85])/256 
darkgreen=np.array([34,85,34])/256 
darkyellow2=np.array([102,102,51])/256 
darkred2=np.array([102,51,51])/256 

blackHEX='#000000'
blueHEX='#332288'
cyanHEX='#88CCEE'
tealHEX='#44AA99'
greenHEX='#117733'
oliveHEX='#999933'
yellowHEX='#EECC66'
roseHEX='#CC6677'
wineHEX='#882255'
purpleHEX='#AA4499'
greyHEX='#DDDDDD'
magentaHEX='#EE3377'
pinkHEX='#FFAABB'
darkyellowHEX='#997700'
darkredHEX='#994455'
redHEX='#CC3311'
orangeHEX='#EE7733'
lightblueHEX='#77AADD'
lightcyanHEX='#99DDFF'
mintHEX='#44BB99'
ppinkHEX='#DE3163'
olive2HEX='#AAAA00'
lightyellowHEX='#EEDD88'
orange2HEX='#EE8866'
pink2HEX='#FFAABB'
palegrayHEX='#555555'
paleblueHEX='#BBCCEE'
palecyanHEX='#CCEEFF'
palegreenHEX='#CCDDAA'
paleyellowHEX='#EEEEBB'
paleredHEX='#FFCCCC'
darkblueHEX='#222255'
darkcyanHEX='#225555'
darkgreenHEX='#225522'
darkyellow2HEX='#666633'
darkred2HEX='#663333'


goodColors=np.hstack((np.vstack((blue,green,olive,rose,wine,purple,grey,cyan,teal,yellow,magenta,black,pink,darkyellow,darkred,orange,lightblue,red,mint,ppink,lightcyan,olive2,lightyellow,orange2,pink2,palegray,paleblue,palecyan,palegreen,paleyellow,palered,darkblue,darkcyan,darkgreen)),np.ones((34,1))))
goodColorsHEX=np.array([blueHEX,greenHEX,oliveHEX,roseHEX,wineHEX,purpleHEX,greyHEX,cyanHEX,tealHEX,yellowHEX,magentaHEX,blackHEX,pinkHEX,darkyellowHEX,darkredHEX,orangeHEX,lightblueHEX,redHEX,mintHEX,ppinkHEX,lightcyanHEX,olive2HEX,lightyellowHEX,orange2HEX,pink2HEX,palegrayHEX,paleblueHEX,palecyanHEX,palegreenHEX,paleyellowHEX,paleredHEX,darkblueHEX,darkcyanHEX,darkgreenHEX])

# species in the order of significance - presorted externally
genus_descending= np.array(['Microbacterium',
 'Stenotrophomonas',
 'Pseudomonas',
 'Serratia',
 'Paracoccus',
 'Escherichia',
 'Ochrobactrum',
 'Streptomyces',
 'Brucella',
 'Pseudochrobactrum',
 'Homo',
 'Roseomonas',
 'Brevundimonas',
 'Achromobacter',
 'Kocuria',
 'Priestia',
 'Sphingobacterium',
 'Bacillus',
 'Debaryomyces',
 'Leucobacter',
 'Rhodococcus',
 'Bordetella',
 'Agrobacterium',
 'Plantibacter',
 'Ralstonia',
 'Sphingomonas',
 'Pseudoxanthomonas',
 'Chryseobacterium',  
 'Moraxella',
 'Flavobacterium',                         
 'Herbaspirillum',
 'Epilithonimonas',              
 'Massilia',
 'Paenibacillus'])

# %%
np.save(outPath+"_genusDescending", genus_descending)    # .npy extension is added if not given
np.save(outPath+"_ColorsRGB", goodColors)
np.save(outPath+"_ColorsHEX", goodColorsHEX)
